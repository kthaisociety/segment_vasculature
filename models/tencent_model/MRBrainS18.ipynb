# %%
import nibabel as nib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_img = nib.load("data/MRBrainS18/images/1.nii.gz")
img_data = train_img.get_fdata()

#plt.imshow(img_data[:,:,50])
img_data.shape
# Out:
# (143, 227, 192)

# %%
label_img = nib.load("model/data/MRBrainS18/labels/1.nii.gz")
img_data = label_img.get_fdata()
plt.imshow(img_data[:,:,50])
